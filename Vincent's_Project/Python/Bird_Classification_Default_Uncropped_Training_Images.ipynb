# %%
"""This cell contains all of the Pre-processing of the training data"""
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers

# Copy images to training, validation and test directories 
import os,shutil, pathlib
original_dir = pathlib.Path("training_data/raw_images")
classes = os.listdir(original_dir)
classes = len(classes)

"""Generatng a Dataset:
Define the desired image size to resize the images from iNaturalist to (PCs with GPUs will be able to run a larger
image size (255,255,3). Note: in the image size below image_size = (200,200) normally you would include the number of
colour channels (,3) at the end but, if it it isn't defined now keras will automatically default the colour channels to 3.
The batch size is also defined in this section, again more powerful machines could run at a higher batch_size, at the 
and complete model training faster but at the detrement of accuracy)"""

image_size = (200,200)
batch_size = 16

"""
Seperate all the training data downloaded from iNaturalist into a training and validation dataset using 
image_dataset_from_directory() provided by keras preprocessing module. This module requires the arguments: 
Path to image directory, 
Validation_split (as a ratio 0.2 = 20% Validation/80% Training), 
Subset is required if validation split is defined in the function. 
Seed is an optional argument for random shuffling and transformation
image_size - preprocesses the images to the defined size before
batch_size - package images in to batches (number = number of images packaged into each batch)
label_mode - labels to be encoded as categorical for categorical entropy loss later when defining the model. 
"""
train_dataset, validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
"training_data/raw_images",
validation_split=0.2,
subset="both",
seed =1227,
image_size = image_size,
batch_size = batch_size,
label_mode = "categorical",
)

"""
Data augmentation adds random rotations and flips when the image is inputted into the first layer of the model,
RandomFlip is set to horizontal due to it unlikely that images of birds captured in the project will be upside down 
"""
data_augmentation = keras.Sequential(
    [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    ]
)
# Apply "data_augmentation" to the training images
train_dataset= train_dataset.map(
    lambda img, label:(data_augmentation(img),label),
    num_parallel_calls=tf.data.AUTOTUNE,
)

# Prefetching samples in GPU memory helps maximise GPU utilisation 
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)
validation_dataset = validation_dataset.prefetch(tf.data.AUTOTUNE)
# Out:
# Found 42956 files belonging to 17 classes.
# Using 34365 files for training.
# Using 8591 files for validation.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
# Build the model 

def make_model(input_shape, num_classes):
    inputs=keras.Input(shape= input_shape)
    
    # Entry block 
    x = data_augmentation(inputs) # Perform data augmentation for gpu training 
    x = layers.Rescaling(1.0/255)(x) # Scale pixel values
    x = layers.Conv2D(128,3,strides = 2, padding="same")(x) 
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    previous_block_activation = x # Set aside residual
    
    for size in [256,512,728]: # Loop through filter sizes for multiple convolutional blocks
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size,3,padding="same")(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.MaxPooling2D(3,strides=2, padding="same")(x)
        
        # Project residual 
        
        residual = layers.Conv2D(size,1, strides =2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x,residual]) # Add back residual 
        previous_block_activation = x # Set aside next residual
        
    x = layers.SeparableConv2D(1024,3,padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.GlobalAveragePooling2D()(x) # Global average pooling to reduce spatial dimensions
    if num_classes ==2: # Check the number of classes/labels for the activation function. 
        activation = "sigmoid"
        units = 1 
    else:
        activation = "softmax"
        units = num_classes 
        
    x = layers.Dropout(0.5)(x) # drop out for regularization 
    
    x = layers.Flatten()(x) # Flatten the output layer for the final dense layer
    
    outputs = layers.Dense(units, activation = activation)(x)
    print(units)
    return keras.Model(inputs,outputs)

"""The model image_size takes the image size defined at the start and adds a 3 into the argument to tell the model to expect
an RGB image with 3 colour channels
"""
model = make_model(input_shape= image_size +(3,),num_classes = classes)
model.summary()
#keras.utils.plot_model(model,show_shapes=True)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 17
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 200, 200, 3)  0           ['input_1[0][0]']
#
#  rescaling (Rescaling)          (None, 200, 200, 3)  0           ['sequential[0][0]']
#
#  conv2d (Conv2D)                (None, 100, 100, 12  3584        ['rescaling[0][0]']
#                                 8)
#
#  batch_normalization (BatchNorm  (None, 100, 100, 12  512        ['conv2d[0][0]']
#  alization)                     8)
#
#  activation (Activation)        (None, 100, 100, 12  0           ['batch_normalization[0][0]']
#                                 8)
#
#  activation_1 (Activation)      (None, 100, 100, 12  0           ['activation[0][0]']
#                                 8)
#
#  separable_conv2d (SeparableCon  (None, 100, 100, 25  34176      ['activation_1[0][0]']
#  v2D)                           6)
#
#  batch_normalization_1 (BatchNo  (None, 100, 100, 25  1024       ['separable_conv2d[0][0]']
#  rmalization)                   6)
#
#  activation_2 (Activation)      (None, 100, 100, 25  0           ['batch_normalization_1[0][0]']
#                                 6)
#
#  separable_conv2d_1 (SeparableC  (None, 100, 100, 25  68096      ['activation_2[0][0]']
#  onv2D)                         6)
#
#  batch_normalization_2 (BatchNo  (None, 100, 100, 25  1024       ['separable_conv2d_1[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d (MaxPooling2D)   (None, 50, 50, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 50, 50, 256)  33024       ['activation[0][0]']
#
#  add (Add)                      (None, 50, 50, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  activation_3 (Activation)      (None, 50, 50, 256)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 50, 50, 512)  133888     ['activation_3[0][0]']
#  onv2D)
#
#  batch_normalization_3 (BatchNo  (None, 50, 50, 512)  2048       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 50, 50, 512)  0           ['batch_normalization_3[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 50, 50, 512)  267264     ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 50, 50, 512)  2048       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 25, 25, 512)  0          ['batch_normalization_4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 25, 25, 512)  131584      ['add[0][0]']
#
#  add_1 (Add)                    (None, 25, 25, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_5 (Activation)      (None, 25, 25, 512)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 25, 25, 728)  378072     ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 728)  2912       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 25, 25, 728)  0           ['batch_normalization_5[0][0]']
#  separable_conv2d_5 (SeparableC  (None, 25, 25, 728)  537264     ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 728)  2912       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 13, 13, 728)  0          ['batch_normalization_6[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 13, 13, 728)  373464      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 13, 13, 728)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 13, 13, 1024  753048     ['add_2[0][0]']
#  onv2D)                         )
#
#  batch_normalization_7 (BatchNo  (None, 13, 13, 1024  4096       ['separable_conv2d_6[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 13, 13, 1024  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['activation_7[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  flatten (Flatten)              (None, 1024)         0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 17)           17425       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 2,747,465
# Trainable params: 2,739,177
# Non-trainable params: 8,288
# __________________________________________________________________________________________________

# %%
# Train the model 
epochs = 20
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = "Species_Classification_Model_Uncropped.h5",
        save_best_only = True,
        monitor="val_loss"),

]
model.compile(
    #optimizer = "rmsprop",
    optimizer = keras.optimizers.Adam(1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
history = model.fit(
    train_dataset,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_dataset,
    #steps_per_epoch = ,
    shuffle = True
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 2148/2148 [==============================] - 355s 163ms/step - loss: 2.7794 - accuracy: 0.1122 - val_loss: 2.7950 - val_accuracy: 0.1216
# Epoch 2/20
#  530/2148 [======>.......................] - ETA: 4:15 - loss: 2.6818 - accuracy: 0.1307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10464\2690529365.py in <module>
#      14     metrics=["accuracy"],
#      15 )
# ---> 16 history = model.fit(
#      17     train_dataset,
#      18     epochs = epochs,
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568                             logs = tmp_logs
#    1569                             end_step = step + data_handler.step_increment
# -> 1570                             callbacks.on_train_batch_end(end_step, logs)
#    1571                             if self.stop_training:
#    1572                                 break
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     468         """
#     469         if self._should_call_train_batch_hooks:
# --> 470             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     471
#     472     def on_test_batch_begin(self, batch, logs=None):
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     315             self._call_batch_begin_hook(mode, batch, logs)
#     316         elif hook == "end":
# --> 317             self._call_batch_end_hook(mode, batch, logs)
#     318         else:
#     319             raise ValueError(
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     338             self._batch_times.append(batch_time)
#     339
# --> 340         self._call_batch_hook_helper(hook_name, batch, logs)
#     341
#     342         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     386         for callback in self.callbacks:
#     387             hook = getattr(callback, hook_name)
# --> 388             hook(batch, logs)
#     389
#     390         if self._check_timing:
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1079
#    1080     def on_train_batch_end(self, batch, logs=None):
# -> 1081         self._batch_update_progbar(batch, logs)
#    1082
#    1083     def on_test_batch_end(self, batch, logs=None):
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1155         if self.verbose == 1:
#    1156             # Only block async when verbose = 1.
# -> 1157             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1159
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     633         return t.item() if np.ndim(t) == 0 else t
#     634
# --> 635     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     636
#     637
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     626         # Don't turn ragged or sparse tensors to NumPy.
#     627         if isinstance(t, tf.Tensor):
# --> 628             t = t.numpy()
#     629         # Strings, ragged and sparse tensors don't have .item(). Return them
#     630         # as-is.
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1155     """
#    1156     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1159
#
# ~\anaconda3\envs\cameratraps-detector\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1121   def _numpy(self):
#    1122     try:
# -> 1123       return self._numpy_internal()
#    1124     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
# Displaying curves of loss and accuracy during training
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy)+1)
plt.plot(epochs,accuracy,"bo",label="Training Accuracy")
plt.plot(epochs,val_accuracy,"b",label="Validation Accuracy")
plt.ylabel("Accuracy %")
plt.xlabel("Epochs")
plt.title("Training and validation accuracy")
plt.legend()
plt.savefig("Species Classification Accuracy Uncropped Training Images.png")
plt.figure()
plt.plot(epochs,loss,"bo",label="Training Loss")
plt.plot(epochs,val_loss,"b",label="Validation Loss")
plt.title("Training and validation loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.legend()
plt.savefig("Species Classification Loss Uncropped Training Images.png")
plt.show()
